# %%
import requests
import time
import re
from lxml import etree

# %%
# 获取某市区域的所有链接
def get_areas(url):
    print('start grabing areas')
    headers = {
        'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/63.0.3239.108 Safari/537.36'}
    
    resposne = requests.get(url, headers=headers)
    content = etree.HTML(resposne.text)
    areas = content.xpath("//dd[@data-index = '0']//div[@class='option-list']/a/text()")
    areas_link = content.xpath("//dd[@data-index = '0']//div[@class='option-list']/a/@href")
    for i in range(1,len(areas)):
        area = areas[i]
        area_link = areas_link[i]
        link = 'https://bj.lianjia.com' + area_link
        print("开始抓取页面")
        get_pages(area, link)

#通过获取某一区域的页数，来拼接某一页的链接
def get_pages(area,area_link):
    headers = {
        'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/63.0.3239.108 Safari/537.36'}
    
    resposne = requests.get(area_link, headers=headers)
    #/html/body/div[4]/div[3]/div[2]/div[2]/div[2]/a[4]
    # <div class="page-box house-lst-page-box" comp-module="page" 
    # page-url="/zufang/haidian/pg{page}/" page-data="{&quot;totalPage&quot;:34,&quot;curPage&quot;:1}">
    pages =  int(re.findall("page-data=\'{\"totalPage\":(\d+),\"curPage\"", resposne.text)[0])
    # print("这个区域有" + str(pages) + "页")
    print(str(area) + "这个区域有" + str(pages) + "页")
    for page in range(1,pages+1):
        url = 'https://bj.lianjia.com/zufang/'+ str(area) + '/pg' + str(page)
        print("开始抓取" + str(page) +"的信息")
        get_house_info(area,url)

#获取某一区域某一页的详细房租信息
def get_house_info(area, url):
    headers = {
        'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/63.0.3239.108 Safari/537.36'}
    time.sleep(2)
    try:
        resposne = requests.get(url, headers=headers)
        content = etree.HTML(resposne.text)
        info=[]
        for i in range(30):
            title = content.xpath("//div[@class='where']/a/span/text()")[i]
            room_type = content.xpath("//div[@class='where']/span[1]/span/text()")[i]
            square = re.findall("(\d+)",content.xpath("//div[@class='where']/span[2]/text()")[i])[0]
            position = content.xpath("//div[@class='where']/span[3]/text()")[i].replace(" ", "")
            try:
                # [\u4E00-\u9FA5]+: 匹配一个或多个中文
                detail_place = re.findall("([\u4E00-\u9FA5]+)租房", content.xpath("//div[@class='other']/div/a/text()")[i])[0]
            except Exception as e:
                detail_place = ""
            floor =re.findall("([\u4E00-\u9FA5]+)\(", content.xpath("//div[@class='other']/div/text()[1]")[i])[0]
            # \d is a digit (a character in the range 0-9), and + means 1 or more times. So, \d+ is 1 or more digits.
            total_floor = re.findall("(\d+)",content.xpath("//div[@class='other']/div/text()[1]")[i])[0]
            try:
                house_year = re.findall("(\d+)",content.xpath("//div[@class='other']/div/text()[2]")[i])[0]
            except Exception as e:
                house_year = ""
            price = content.xpath("//div[@class='col-3']/div/span/text()")[i]
            with open('链家北京租房.txt','a',encoding='utf-8') as f:
                f.write(area + ',' + title + ',' + room_type + ',' + square + ',' +position+
                    ','+ detail_place+','+floor+','+total_floor+','+price+','+house_year+'\n')        
        
    except Exception as e:
        print( 'ooops! connecting error, retrying.....')
        time.sleep(20)
        return get_house_info(area, url)


def main():
    print('start!')
    url = 'https://bj.lianjia.com/zufang'
    get_areas(url)


if __name__ == '__main__':
    main()
# Out:
# start!
# start grabing areas
# 开始抓取页面
# 东城这个区域有14页
# 开始抓取1的信息
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# 开始抓取2的信息
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# 开始抓取3的信息
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# 开始抓取4的信息
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# 开始抓取5的信息
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# 开始抓取6的信息
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# 开始抓取7的信息
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# 开始抓取8的信息
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# 开始抓取9的信息
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# 开始抓取10的信息
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# 开始抓取11的信息
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# 开始抓取12的信息
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# 开始抓取13的信息
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# 开始抓取14的信息
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# 开始抓取页面
# 西城这个区域有20页
# 开始抓取1的信息
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# 开始抓取2的信息
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# 开始抓取3的信息
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# 开始抓取4的信息
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# 开始抓取5的信息
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# 开始抓取6的信息
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# 开始抓取7的信息
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# 开始抓取8的信息
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# 开始抓取9的信息
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# 开始抓取10的信息
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# 开始抓取11的信息
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# 开始抓取12的信息
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# 开始抓取13的信息
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# 开始抓取14的信息
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# 开始抓取15的信息
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# 开始抓取16的信息
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# 开始抓取17的信息
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# 开始抓取18的信息
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# 开始抓取19的信息
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# 开始抓取20的信息
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# 开始抓取页面
# 朝阳这个区域有72页
# 开始抓取1的信息
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# 开始抓取2的信息
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# ...
# 开始抓取3的信息
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# 开始抓取4的信息
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# 开始抓取5的信息
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# 开始抓取6的信息
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# 开始抓取7的信息
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# 开始抓取8的信息
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# 开始抓取9的信息
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# 开始抓取10的信息
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# 开始抓取11的信息
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# 开始抓取12的信息
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# 开始抓取13的信息
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# writing work has done!continue the next page
# 开始抓取页面
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-2-06089bd4e9e8> in <module>()
#      76
#      77 if __name__ == '__main__':
# ---> 78     main()
#
# <ipython-input-2-06089bd4e9e8> in main()
#      72     print('start!')
#      73     url = 'https://bj.lianjia.com/zufang'
# ---> 74     get_areas(url)
#      75
#      76
#
# <ipython-input-2-06089bd4e9e8> in get_areas(url)
#      14         link = 'https://bj.lianjia.com' + area_link
#      15         print("开始抓取页面")
# ---> 16         get_pages(area, link)
#      17
#      18 #通过获取某一区域的页数，来拼接某一页的链接
#
# <ipython-input-2-06089bd4e9e8> in get_pages(area, area_link)
#      22
#      23     resposne = requests.get(area_link, headers=headers)
# ---> 24     pages =  int(re.findall("page-data=\'{\"totalPage\":(\d+),\"curPage\"", resposne.text)[0])
#      25     # print("这个区域有" + str(pages) + "页")
#      26     print(str(area) + "这个区域有" + str(pages) + "页")
#
# IndexError: list index out of range

# %% [markdown]
# list index out of range

# %% [markdown]
# 抓到了“门头沟这个区域有13页”， 还有6个区没有抓到
#
# 直到燕郊，平谷，怀柔，密云，延庆，是没有数据的
#
# 而且到了燕郊的时候，网址也变了。原来是https://bj.lianjia.com/zufang ， 之后就变成了https://lf.lianjia.com/zufang/yanjiao/ .
#
# 并多出了燕郊，香河，广阳，安次，廊坊经济技术开发区。 而这些地方，其实是河北，不再属于北京了。

# %%
import pandas as pd
f = open('链家北京租房.txt')
df = pd.read_csv(f, sep = ',', header = None, encoding = 'utf-8',
                names = ['area', 'title', 'room_type', 'square', 'position', 'detail_place', 'floor', 'total_floor', 'price', 'house_year'])
df.head()
# Out:
#   area     title room_type  square position detail_place floor  total_floor  \
# 0   东城  正东国际大厦      3室1厅       210       东南          东直门   中楼层           27
# 1   东城  当代MOMA      3室1厅       182       西北          东直门   中楼层           21
# 2   东城  当代MOMA      4室2厅       331       南北          东直门   低楼层           19
# 3   东城    京宝花园      3室1厅       194       东西          安定门   低楼层           12
# 4   东城     前门前     2房间1卫       125        南           天坛   高楼层            8
#
#    price  house_year
# 0  30000      2004.0
# 1  35000      2008.0
# 2  55000      2008.0
# 3  24000      1994.0
# 4  15000      2009.0

# %%
df.tail()
# Out:
#       area       title room_type  square position detail_place floor  \
# 10201  门头沟      万科星园      3室2厅       138       南北       奥林匹克公园   高楼层
# 10202  门头沟    广安门外南街      1室1厅        40        南          天宁寺   中楼层
# 10203  门头沟      晓月新城      1室1厅        55        西          卢沟桥   高楼层
# 10204  门头沟  华业东方玫瑰C区      2室2厅        89        南          临河里   中楼层
# 10205  门头沟  华业东方玫瑰C区      2室2厅        89        南          临河里   中楼层
#
#        total_floor  price  house_year
# 10201           26  15500      2000.0
# 10202            5   4800      1991.0
# 10203           24   3800      2007.0
# 10204           26   6000      2014.0
# 10205           26   5900      2014.0

# %%
df.describe()
# Out:
#              square   total_floor          price   house_year
# count  10206.000000  10206.000000   10206.000000  9790.000000
# mean     113.760141     13.223986   12681.222516  2002.106435
# std       83.747383      8.305485   13584.301457     9.061819
# min       11.000000      0.000000     566.000000  1950.000000
# 25%       61.000000      6.000000    5500.000000  1998.000000
# 50%       89.000000     12.000000    8000.000000  2004.000000
# 75%      138.000000     19.000000   15000.000000  2008.000000
# max     1133.000000     52.000000  250000.000000  2017.000000

# %% [markdown]
# ### 北京路段_房屋均价分布图

# %%
import matplotlib.pyplot as plt 
from pyecharts import ThemeRiver
from pyecharts import Line, Bar, Overlap

# 按照具体区域名称，按平均租金高低进行前20名的排序
area = df.groupby(['area'])
house_com = area['price'].agg(['mean','count'])
house_com.reset_index(inplace=True)
area_main = house_com.sort_values('count',ascending=False)[0:20]

# 属性
attr = area_main['area']
v1 = area_main['count']
v2 = area_main['mean']

# 画线状图
line = Line("北京主要区县房租均价")
line.add("房屋均价",attr,v2,is_stack=True,xaxis_rotate=30,yaxix_min=4.2,
    mark_point=['min','max'],xaxis_interval=0,line_color='lightblue',
    line_width=4,mark_point_textcolor='black',mark_point_color='lightblue',
    is_splitline_show=False)

# 按照具体区域名称，按平均租金高低进行前20名的排序
bar = Bar("北京主要区县房屋数量")
bar.add("区县",attr,v1,is_stack=True,xaxis_rotate=30,yaxix_min=4.2,
    xaxis_interval=0,is_splitline_show=False)

overlap = Overlap()
overlap.add(bar)
overlap.add(line,yaxis_index=1,is_add_yaxis=True)
overlap.render('北京区县_房屋均价分布图.html')

# %%
import matplotlib.pyplot as plt 
from pyecharts import ThemeRiver
from pyecharts import Line, Bar, Overlap

# 按照具体区域名称，按平均租金高低进行前20名的排序
detail_place = df.groupby(['detail_place'])
house_com = detail_place['price'].agg(['mean','count'])
house_com.reset_index(inplace=True)
detail_place_main = house_com.sort_values('count',ascending=False)[0:20]

# 属性
attr = detail_place_main['detail_place']
v1 = detail_place_main['count']
v2 = detail_place_main['mean']

# 画线状图
line = Line("北京主要路段房租均价")
line.add("房屋均价",attr,v2,is_stack=True,xaxis_rotate=30,yaxix_min=4.2,
    mark_point=['min','max'],xaxis_interval=0,line_color='lightblue',
    line_width=4,mark_point_textcolor='black',mark_point_color='lightblue',
    is_splitline_show=False)

# 按照具体区域名称，按平均租金高低进行前20名的排序
bar = Bar("北京主要路段房屋数量")
bar.add("路段",attr,v1,is_stack=True,xaxis_rotate=30,yaxix_min=4.2,
    xaxis_interval=0,is_splitline_show=False)

overlap = Overlap()
overlap.add(bar)
overlap.add(line,yaxis_index=1,is_add_yaxis=True)
overlap.render('北京路段_房屋均价分布图.html')

# %% [markdown]
# ### 房源价格区间分布图

# %%
price_info = df[['area', 'price']]

#对价格分区
bins = [0,1000,1500,2000,2500,3000,4000,5000,6000,8000,10000]
level = ['0-1000元','1000-1500元', '1500-2000元', '2000-3000元', '3000-4000元', '4000-5000元', '5000-6000元', '6000-8000元', '8000-1000元','10000元以上']
price_stage = pd.cut(price_info['price'], bins = bins,labels = level).value_counts().sort_index()

attr = price_stage.index
v1 = price_stage.values

bar = Bar("价格区间&房源数量分布")
bar.add("",attr,v1,is_stack=True,xaxis_rotate=30,yaxix_min=4.2,
    xaxis_interval=0,is_splitline_show=False)

bar.render('价格区间&房源数量分布.html')

# %% [markdown]
# ### 房屋面积分布

# %%
from pyecharts import Pie

bins =[0,30,60,90,120,150,200,300,400,700]
level = ['0-30', '30-60', '60-90', '90-120', '120-150', '150-200', '200-300','300-400','400+']
df['square_level'] = pd.cut(df['square'],bins = bins,labels = level)

df_digit= df[['area', 'room_type', 'square', 'position', 'total_floor', 'floor', 'house_year', 'price', 'square_level']]
s = df_digit['square_level'].value_counts()

attr = s.index
v1 = s.values

pie = Pie("房屋面积分布",title_pos='center')

pie.add(
    "",
    attr,
    v1,
    radius=[40, 75],
    label_text_color=None,
    is_label_show=True,
    legend_orient="vertical",
    legend_pos="left",
)

overlap = Overlap()
overlap.add(pie)
overlap.render('房屋面积分布.html')

#房屋面积&价位分布
bins =[0,30,60,90,120,150,200,300,400,700]
level = ['0-30平米', '30-60平米', '60-90平米', '90-120平米', '120-150平米', '150-200平米', '200-300平米','300-400平米','400+平米']
df['square_level'] = pd.cut(df['square'],bins = bins,labels = level)

df_digit= df[['area', 'room_type', 'square', 'position', 'total_floor', 'floor', 'house_year', 'price', 'square_level']]

square = df_digit[['square_level','price']]
prices = square.groupby('square_level').mean().reset_index()
amount = square.groupby('square_level').count().reset_index()

attr = prices['square_level']
v1 = prices['price']

pie = Bar("房屋面积&价位分布")
pie.add("", attr, v1, is_label_show=True)
pie.render()

bar = Bar("房屋面积&价位分布")
bar.add("",attr,v1,is_stack=True,xaxis_rotate=30,yaxix_min=4.2,
    xaxis_interval=0,is_splitline_show=False)


overlap = Overlap()
overlap.add(bar)
overlap.render('房屋面积&价位分布.html')
